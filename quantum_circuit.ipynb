# %%
from qiskit import *

# %%
qr=QuantumRegister(1)

# %%
qc=ClassicalRegister(1)

# %%
cir=QuantumCircuit(qr,qc)

# %%
cir.draw()
# Out:
#
#   q0:
#
# c0: 1/

# %%
cir.x(qr[0])

# %%
cir.draw()
# Out:
#       ┌───┐
#   q0: ┤ X ├
#       └───┘
# c0: 1/═════

# %%
cir.measure(qr,qc)

# %%
cir.draw()
# Out:
#       ┌───┐┌─┐
#   q0: ┤ X ├┤M├
#       └───┘└╥┘
# c0: 1/══════╩═
#             0

# %%
simulator=BasicAer.get_backend("qasm_simulator")

# %%
res=execute(cir,backend=simulator).result()

# %%
print(res)
# Out:
# <qiskit.providers.basicaer.basicaerjob.BasicAerJob object at 0x7f79ffc14ca0>

# %%
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(res.get_counts(cir))

# %%
IBMQ.save_account('7cd5664973bf6ce405272fc6fa2bd7684625b387b768de3dd459fa38dd3cdc417387fa4c306562485e0bb6ddb46fd20fcd24da495248304d90d155b52011fd6f')

# %%
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
provider=IBMQ.get_provider('ibm-q')

# %%
qcomp=provider.get_backend('ibmq_quito')

# %%
job=execute(cir,backend=qcomp)

# %%
from qiskit.tools.monitor import job_monitor

# %%
job_monitor(job)
# Out:
# Job Status: job incurred error

# %%
res=job.result()
# Out:
# ---------------------------------------------------------------------------
# IBMQJobFailureError                       Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 res=job.result()
#
# File ~/.local/lib/python3.10/site-packages/qiskit/providers/ibmq/job/ibmqjob.py:290, in IBMQJob.result(self, timeout, wait, partial, refresh)
#     288         else:
#     289             error_message = ": " + error_message
# --> 290         raise IBMQJobFailureError(
#     291             'Unable to retrieve result for job {}. Job has failed{}'.format(
#     292                 self.job_id(), error_message))
#     293 else:
#     294     self._retrieve_result(refresh=refresh)
#
# IBMQJobFailureError: 'Unable to retrieve result for job 6359f79a333aebde6889f15e. Job has failed: Internal Error. Error code: 9443.'

# %%
plot_histogram(res.get_counts(cir))

# %%
from qiskit import *

# %%
from math import pi

# %%
qr=QuantumRegister(1)

# %%
cr=ClassicalRegister(1)

# %%
qc=QuantumCircuit(qr,cr)

# %%
qc.draw()
# Out:
#
#   q0:
#
# c0: 1/

# %%
qc.u3(pi,0,0,qr[0])
qc.measure(qr,cr)
# Out:
# /tmp/ipykernel_2255/791344999.py:1: DeprecationWarning: The QuantumCircuit.u3 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use QuantumCircuit.u instead, which acts identically. Alternatively, you can decompose u3 in terms of QuantumCircuit.p and QuantumCircuit.sx: u3(ϴ,φ,λ) = p(φ+π) sx p(ϴ+π) sx p(λ) (2 pulses on hardware).
#   qc.u3(pi,0,0,qr[0])

# %%
qc.draw()
# Out:
#       ┌───────────┐┌─┐
#   q0: ┤ U3(π,0,0) ├┤M├
#       └───────────┘└╥┘
# c0: 1/══════════════╩═
#                     0

# %%
simulator=BasicAer.get_backend("qasm_simulator")

# %%
job=execute(qc,backend=simulator)

# %%
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(job.result().get_counts())

# %%
plot_histogram(job.result().get_counts(qc))

# %%
qrr=QuantumRegister(1)
crr=ClassicalRegister(1)

# %%
qcc=QuantumCircuit(qrr,crr)

# %%
qcc.x(qrr[0])

# %%
qcc.z(qrr[0])

# %%
qcc.draw()
# Out:
#       ┌───┐┌───┐
#   q5: ┤ X ├┤ Z ├
#       └───┘└───┘
# c1: 1/══════════

# %%
qcc.measure(qrr,crr)

# %%
simu=BasicAer.get_backend("qasm_simulator")

# %%
result=execute(qcc,backend=simu).result()

# %%
plot_histogram(result.get_counts(qcc))

# %%
qr2=QuantumRegister(2)

# %%
cr2=ClassicalRegister(2)

# %%
qc=QuantumCircuit(qr2,cr2)

# %%
qc.h(qr2[0])

# %%
qc.cx(qr2[0],qr2[1])

# %%
qc.draw()
# Out:
#        ┌───┐
# q14_0: ┤ H ├──■──
#        └───┘┌─┴─┐
# q14_1: ─────┤ X ├
#             └───┘
#  c2: 2/══════════

# %%
qc.measure(qr2,cr2)

# %%
simu=BasicAer.get_backend("qasm_simulator")

# %%
result=execute(qc,backend=simu).result()

# %%
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(result.get_counts(qc))

# %%
IBMQ.save_account('7cd5664973bf6ce405272fc6fa2bd7684625b387b768de3dd459fa38dd3cdc417387fa4c306562485e0bb6ddb46fd20fcd24da495248304d90d155b52011fd6f',overwrite=True)

# %%
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
pr=IBMQ.get_provider('ibm-q')

# %%
qcomp=pr.get_backend("ibmq_quito")

# %%
job=execute(qc,backend=qcomp)

# %%
from qiskit.tools.monitor import job_monitor

# %%
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
res=job.result()

# %%
plot_histogram(res.get_counts(qc))

# %%
qiskit.tools
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 qiskit.tools
#
# NameError: name 'qiskit' is not defined

# %%
from qiskit import *

# %%
from qiskit.tools.monitor import job_monitor
from qiskit.visualization import plot_histogram

# %%
qr=QuantumRegister(2)

# %%
cr=ClassicalRegister(2)

# %%
qc=QuantumCircuit(qr,cr)

# %%
qc.x(qr[0])

# %%
qc.draw()
# Out:
#        ┌───┐
# q23_0: ┤ X ├
#        └───┘
# q23_1: ─────
#
#  c1: 2/═════

# %%
qc.h(qr[0])

# %%
qc.cx(qr[0],qr[1])

# %%
qc.draw()
# Out:
#        ┌───┐┌───┐
# q23_0: ┤ X ├┤ H ├──■──
#        └───┘└───┘┌─┴─┐
# q23_1: ──────────┤ X ├
#                  └───┘
#  c1: 2/═══════════════

# %%
qc.measure(qr,cr)

# %%
simu=BasicAer.get_backend("qasm_simulator")

# %%
result=execute(qc,backend=simu).result()

# %%
plot_histogram(result.get_counts(qc))

# %%
IBMQ.save_account('c10fa12997ad898683c72c5496c720b9657d7b96ce93b3f443366854e87973466f32f0bd9d807b4c147a63ac230eb03987972bdf400193154e11bdd834503a58',overwrite=True)

# %%
IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2022-11-12 10:11:54,301: Credentials are already in use. The existing account in the session will be replaced.
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
pr=IBMQ.get_provider("ibm-q")

# %%
qcomp=pr.get_backend("ibmq_manila")

# %%
job=execute(qc,backend=qcomp)

# %%
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
result=job.result()

# %%
plot_histogram(result.get_counts(qc))

# %%
qr1=QuantumRegister(2)
cr1=ClassicalRegister(2)

# %%
qc1=QuantumCircuit(qr1,cr1)

# %%
qc1.h(qr1[0])

# %%
qc1.x(qr1[1])

# %%
qc1.cx(qr1[0],qr1[1])

# %%
qc1.measure(qr1,cr1)

# %%
simu=BasicAer.get_backend("qasm_simulator")

# %%
job=execute(qc1,backend=simu).result()

# %%
print(job.get_counts())
# Out:
# {'01': 488, '10': 536}

# %%
plot_histogram(job.get_counts(qc1))

# %%
qcomp1=pr.get_backend("ibmq_manila")

# %%
job1=execute(qc1,backend=qcomp1)

# %%
job_monitor(job1)
# Out:
# Job Status: job has successfully run

# %%
plot_histogram(job1.result().get_counts(q))

# %%
print(job1.result().get_counts())
# Out:
# {'00': 152, '01': 1819, '10': 1909, '11': 120}

# %%
from qiskit import *
from qiskit.visualization import plot_histogram
from qiskit.tools.monitor import job_monitor

# %%
qr2=QuantumRegister(2)

# %%
cr2=ClassicalRegister(2)

# %%
qc2=QuantumCircuit(qr2,cr2)

# %%
qc2.x(qr2[0])

# %%
qc2.x(qr2[1])

# %%
qc2.h(qr2[0])

# %%
qc2.cx(qr2[0],qr2[1])

# %%
qc2.draw()
# Out:
#       ┌───┐┌───┐
# q0_0: ┤ X ├┤ H ├──■──
#       ├───┤└───┘┌─┴─┐
# q0_1: ┤ X ├─────┤ X ├
#       └───┘     └───┘
# c0: 2/═══════════════

# %%
simu=BasicAer.get_backend("qasm_simulator")

# %%
qc2.measure(qr2,cr2)

# %%
job3=execute(qc2,backend=simu)

# %%
print(job3.result().get_counts())
# Out:
# {'10': 485, '01': 539}

# %%
plot_histogram(job3.result().get_counts())

# %%
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
pr=IBMQ.get_provider("ibm-q")

# %%
qcomp2=pr.get_backend("ibmq_manila")

# %%
job4=execute(qc2,backend=qcomp2)

# %%
job_monitor(job4)
# Out:
# Job Status: job has successfully run

# %%
print(job4.result().get_counts())
# Out:
# {'00': 117, '01': 1728, '10': 1974, '11': 181}

# %%
plot_histogram(job4.result().get_counts())

# %%
from qiskit import *

# %%
bell=QuantumCircuit(2,2)

# %%
bell.h(0)

# %%
bell.cx(0,1)

# %%
meas=QuantumCircuit(2,2)

# %%
meas.measure([0,1],[0,1])

# %%
backend=BasicAer.get_backend('qasm_simulator')

# %%
circ=bell.compose(meas)

# %%
result=backend.run(transpile(circ,backend)).result()

# %%
count=result.get_counts(circ)

# %%
print(count)
# Out:
# {'00': 521, '11': 503}

# %%
from qiskit.visualization import plot_bloch_multivector,plot_state_qsphere,plot_histogram,plot_bloch_vector

# %%
# bell=QuantumCircuit(1,1)

# %%
bell.h(0)

# %%
bell.y(0)

# %%
backend=BasicAer.get_backend('statevector_simulator')

# %%
result=backend.run(transpile(bell,backend)).result()

# %%
ps1=result.get_statevector(bell)

# %%
plot_bloch_multivector(ps1)

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in ./.local/lib/python3.10/site-packages (0.12.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/lib/python3/dist-packages (from seaborn) (3.5.2)
# Requirement already satisfied: numpy>=1.17 in /usr/lib/python3/dist-packages (from seaborn) (1.21.5)
# Requirement already satisfied: pandas>=0.25 in /usr/lib/python3/dist-packages (from seaborn) (1.3.5)

# %%
# plot_state_qsphere(ps1)

# %%
# plot_bloch_vector(['00','11'])

# %%
q=QuantumCircuit(1,1)

# %%
q.y(0)

# %%
plot_bloch_multivector(q)

# %%
from qiskit_textbook.widgets import bloch_calc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [79], line 1
# ----> 1 from qiskit_textbook.widgets import bloch_calc
#
# ModuleNotFoundError: No module named 'qiskit_textbook'

# %%
# !pip install qiskit_textbook
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement qiskit_textbook (from versions: none)
# ERROR: No matching distribution found for qiskit_textbook

# %%
from qiskit_textbook.widgets import binary_widget
binary_widget(nbits=5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [81], line 1
# ----> 1 from qiskit_textbook.widgets import binary_widget
#       2 binary_widget(nbits=5)
#
# ModuleNotFoundError: No module named 'qiskit_textbook'

# %%
print("Just adding for update automatically on github repo using shell script cronjob")
# Out:
# Just adding for update automatically on github repo using shell script cronjob

# %%
print("Added Second Line to Check Automatic Update")
# Out:
# Added Second Line to Check Automatic Update

# %%
print("third")
# Out:
# third

# %%
print($$$)
# Out:
#   Cell In [2], line 1
#     print($$$)
#           ^
# SyntaxError: invalid syntax

# %%
print(000)
# Out:
# 0
